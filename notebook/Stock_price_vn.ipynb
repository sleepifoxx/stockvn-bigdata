# %% [markdown]
# # Thực hiện đọc dữ liệu từ hdfs

# %% [markdown]
# Dữ liệu đã được lưu trữ trên hdfs, hiện tại ta cần sử dụng pyspark để đọc dữ liệu ra và xử lý. Cụm spark đã được bật, ta có thể xem thông tin của cả cụm trên web ui host post của spark-master là 0.0.0.0:8080 (truy cập qua localhost) hoặc 172.19.0.2:8080 (truy cập qua ip của container trong docker, xem thông tin bằng lệnh docker network inspect).

# %%
# !pip install tensorflow==2.10.1
# Out:
# Requirement already satisfied: tensorflow==2.10.1 in /opt/conda/lib/python3.10/site-packages (2.10.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.19.6)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (18.1.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (4.15.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.4.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.10.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.4.0)
# Requirement already satisfied: numpy>=1.20 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.23.4)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.10.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.75.1)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.0.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (65.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (2.3.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.37.1)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (3.7.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (0.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (25.9.23)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow==2.10.1) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow==2.10.1) (0.37.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.41.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.1.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->tensorflow==2.10.1) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (4.9.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (6.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.4.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.1) (3.2.2)

# %%
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
#Truy cập vào master của cụm tại địa chỉ 172.19.0.4:7077 với tên chương trình là Stock_price_analysis
spark = SparkSession.builder.master("spark://172.18.0.2:7077").appName("Stock_price_analysis").getOrCreate()

# %% [markdown]
# Ta có thể  truy cập vào địa chỉ web ui của spark-master để xem thông tin của chương trình đang chạy

# %% [markdown]
# Tiếp theo ta sẽ sử dụng spark session vừa tạo để truy cập vào hdfs và lấy dữ liệu ra để xử lý. Cụ thể ta sẽ truy cập vào địa chỉ của namenode trên hdfs là namenode:9000

# %% [markdown]
# # Một số phân tích cơ bản
#
# Ta lấy dữ liệu dataframe từ spark như thông thường.
#
# Ở đây ta so sánh dữ liệu chứng khoán của 5 công ty lớn:
#
# #### Facebook (mã FB)
#
# #### Alibaba (mã BABA)
#
# #### Apple (mã AAPL)
#
# #### Cloudflare (mã NET)
#
# #### Zoom meeting (mã ZM)

# %%
df_VIC = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/stockvn/VIC.csv")

df_VCB = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/stockvn/VCB.csv")

df_FPT = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/stockvn/FPT.csv")

df_HPG = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/stockvn/HPG.csv")

df_GAS = spark.read.format("csv").option("header", "true")\
.option("inferSchema", "true").load("hdfs://namenode:9000/user/root/stockvn/GAS.csv")

# %% [markdown]
# Sau khi lấy dữ liệu, ta thực hiện việc thêm cột Mean để tìm trung bình của mã chứng khoán trong ngày.
#
# Từ đó ta vẽ được biểu đồ để so sánh các mã chứng khoán.

# %%
from pyspark.sql.functions import year, expr

df_VICmean = df_VIC.withColumn("mean", expr('(high+low)/2'))
df_VCBmean = df_VCB.withColumn("mean", expr('(high+low)/2'))
df_FPTmean = df_FPT.withColumn("mean", expr('(high+low)/2'))
df_HPGmean = df_HPG.withColumn("mean", expr('(high+low)/2'))
df_GASmean = df_GAS.withColumn("mean", expr('(high+low)/2'))

# %% [markdown]
# Để dễ sử dụng thư viện đồ thị matplotlib, ta chuyển các dữ liệu dataframes về dạng pandas.

# %%
df_VICmean = df_VICmean.toPandas()
df_VCBmean = df_VCBmean.toPandas()
df_FPTmean = df_FPTmean.toPandas()
df_HPGmean = df_HPGmean.toPandas()
df_GASmean = df_GASmean.toPandas()
# Out:
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)

# %% [markdown]
# Kết quả so sánh chỉ số trung bình trong ngày của các mã nói trên trong đồ thị

# %%
ax = df_VICmean.plot(x='time', y= 'mean', label='VIC', figsize=(16,6))
ax = df_VCBmean.plot(ax=ax, x= 'time', y= 'mean',label='VCB')
ax = df_HPGmean.plot(ax=ax, x= 'time', y= 'mean',label='HPG')
ax = df_GASmean.plot(ax=ax, x= 'time', y= 'mean',label='GAS')
df_FPTmean.plot(ax=ax, x= 'time', y= 'mean',label='FPT')
# Out:
# <AxesSubplot: xlabel='time'>

# %% [markdown]
# Ta đánh giá sự thay đổi của các mã của các công ty Facebook, Alibaba và Zoom trên theo ngày (tính theo %) (Apple và Cloudfare ta không xét do thời gian quá lớn hoặc quá nhỏ)

# %%
df_VICmean['change']= (df_VICmean['close']/df_VICmean['close'].shift(1)) - 1 
df_VCBmean['change']= (df_VCBmean['close']/df_VCBmean['close'].shift(1)) - 1 
df_GASmean['change']= (df_GASmean['close']/df_GASmean['close'].shift(1)) - 1

# %% [markdown]
# Sau đó, ta vẽ biểu đồ cột thể hiện sự thay đổi của các mã theo ngày

# %%
df_VICmean['change'].hist(bins=100, label='VIC',alpha=0.5)
df_VCBmean['change'].hist(bins=100, label='VCB', alpha=0.5)
df_GASmean['change'].hist(bins=100, label='GAS', alpha=0.5)
plt.legend()

# %% [markdown]
# Biểu đồ trên thể hiện sự biến động của từng mã. Số lượng gần 0 càng nhiều chứng tỏ là mã càng biến động ít và ngược lại.
#
# Ta vẽ biểu đồ đường để miêu tả rõ hơn điều đó

# %%
df_VICmean['change'].plot(kind= 'kde', label = 'VIC')
df_VCBmean['change'].plot(kind= 'kde', label = 'VCB')
df_GASmean['change'].plot(kind= 'kde', label = 'GAS')
plt.legend()

# %% [markdown]
# Từ biểu đồ trên, ta thấy sự biến động của các mã đều gần giống với phân phối chuẩn có giá trị trung bình là 0.

# %% [markdown]
# # Dùng mô hình học máy để dự đoán tình hình chứng khoán

# %% [markdown]
# Trong phần này chúng em sẽ tính giá trị trung bình của cổ phiếu công ty Gabelli Equity Trust Inc (mã là GAB). Rồi sử dụng một mô hình học máy đơn giản để dự đoán giá cổ phiếu trung bình của công ty. Chúng em dùng các thông tin từ trước năm 2020 cho việc training và thông tin của năm 2020 cho việc testing.

# %%
df = spark.read.format("csv")\
.option("header", "true")\
.option("inferSchema", "true")\
.load("hdfs://namenode:9000/user/root/stockvn/VIC.csv")

# %%
df.show(5)
# Out:
# +-------------------+----+----+----+-----+-------+
# |               time|open|high| low|close| volume|
# +-------------------+----+----+----+-----+-------+
# |2007-09-19 00:00:00|4.88|4.88|4.88| 4.88| 307840|
# |2007-09-20 00:00:00|5.11|5.11|5.07| 5.11| 794790|
# |2007-09-21 00:00:00|5.35|5.35|5.27| 5.35|1224660|
# |2007-09-24 00:00:00|5.58|5.58|5.58| 5.58| 551130|
# |2007-09-25 00:00:00|5.85|5.85|5.78| 5.85| 962110|
# +-------------------+----+----+----+-----+-------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import expr, col, column
df = df.withColumn("mean", expr('(high+low)/2'))  #Thêm một cột giá trị mean ( được tính bằng trung bình của low và high)

# %%
df.show(5)
# Out:
# +-------------------+----+----+----+-----+-------+------------------+
# |               time|open|high| low|close| volume|              mean|
# +-------------------+----+----+----+-----+-------+------------------+
# |2007-09-19 00:00:00|4.88|4.88|4.88| 4.88| 307840|              4.88|
# |2007-09-20 00:00:00|5.11|5.11|5.07| 5.11| 794790|              5.09|
# |2007-09-21 00:00:00|5.35|5.35|5.27| 5.35|1224660|              5.31|
# |2007-09-24 00:00:00|5.58|5.58|5.58| 5.58| 551130|              5.58|
# |2007-09-25 00:00:00|5.85|5.85|5.78| 5.85| 962110|5.8149999999999995|
# +-------------------+----+----+----+-----+-------+------------------+
# only showing top 5 rows

# %%
asc_df = df.sort(df.time.asc()) #Sắp xếp các cột theo tứ tự tăng dần của thời gian

# %%
asc_df.show(5)
# Out:
# +-------------------+----+----+----+-----+-------+------------------+
# |               time|open|high| low|close| volume|              mean|
# +-------------------+----+----+----+-----+-------+------------------+
# |2007-09-19 00:00:00|4.88|4.88|4.88| 4.88| 307840|              4.88|
# |2007-09-20 00:00:00|5.11|5.11|5.07| 5.11| 794790|              5.09|
# |2007-09-21 00:00:00|5.35|5.35|5.27| 5.35|1224660|              5.31|
# |2007-09-24 00:00:00|5.58|5.58|5.58| 5.58| 551130|              5.58|
# |2007-09-25 00:00:00|5.85|5.85|5.78| 5.85| 962110|5.8149999999999995|
# +-------------------+----+----+----+-----+-------+------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import year
df_test = asc_df.filter(year("time") > 2024) #tách ra tập test là tập gồm thông tin của năm 2020

# %%
df_test.show(5)
# Out:
# +-------------------+-----+-----+-----+-----+-------+------------------+
# |               time| open| high|  low|close| volume|              mean|
# +-------------------+-----+-----+-----+-----+-------+------------------+
# |2025-01-02 00:00:00| 40.5|40.55| 40.3|40.55|1340500|            40.425|
# |2025-01-03 00:00:00|40.55|40.55|40.15| 40.5|1729100|40.349999999999994|
# |2025-01-06 00:00:00| 40.4| 40.5| 40.3| 40.5|1625900|              40.4|
# |2025-01-07 00:00:00| 40.3|40.55| 40.2| 40.5|1965000|            40.375|
# |2025-01-08 00:00:00| 40.4|40.55| 40.3| 40.5| 925800|            40.425|
# +-------------------+-----+-----+-----+-----+-------+------------------+
# only showing top 5 rows

# %%
df_train = asc_df.subtract(df_test)   #tách ra tập train
df_train.count()
# Out:
# 4313

# %%
df_train = df_train.sort(df_train.time.asc())   #sắp xếp lại tập train
df_train.show(5)
# Out:
# +-------------------+----+----+----+-----+-------+------------------+
# |               time|open|high| low|close| volume|              mean|
# +-------------------+----+----+----+-----+-------+------------------+
# |2007-09-19 00:00:00|4.88|4.88|4.88| 4.88| 307840|              4.88|
# |2007-09-20 00:00:00|5.11|5.11|5.07| 5.11| 794790|              5.09|
# |2007-09-21 00:00:00|5.35|5.35|5.27| 5.35|1224660|              5.31|
# |2007-09-24 00:00:00|5.58|5.58|5.58| 5.58| 551130|              5.58|
# |2007-09-25 00:00:00|5.85|5.85|5.78| 5.85| 962110|5.8149999999999995|
# +-------------------+----+----+----+-----+-------+------------------+
# only showing top 5 rows

# %%
dataset_train = df_train.toPandas()
# Out:
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (2.10.0)

# %%
# !pip install tensorflow

# %%
# Import những thư viện cần thiết
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os.path
from os import path
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# Thuc hien scale du lieu gia ve khoang 0,1
training_set = dataset_train.iloc[:, 6:7].values
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)

# %% [markdown]
# Tạo dữ liệu train, X = 60 time steps, Y =  1 time step, có nghĩa lấy dữ liệu của 60 ngày trước để dự đoán cho ngày tiếp theo hay có thể hiểu là lấy 60 ngày trước làm đầu vào, và đầu ra của mô hình sẽ là ngày tiếp theo

# %%
# Tạo dữ liệu train 
X_train = []
y_train = []
no_of_sample = len(training_set)

for i in range(60, no_of_sample):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Xây dựng model LSTM
regressor = Sequential()
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))
regressor.add(Dense(units = 1))
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Nếu tồn tại model thì load lại nếu không thì thực hiện train 
if path.exists("mymodel.h5"):
    regressor.load_weights("mymodel.h5")
else:
    regressor.fit(X_train, y_train, epochs = 20, batch_size = 32)
    regressor.save("mymodel.h5")
# Out:
# Epoch 1/20
# 133/133 [==============================] - 18s 135ms/step - loss: 0.0015
# Epoch 2/20
# 133/133 [==============================] - 18s 137ms/step - loss: 0.0015
# Epoch 3/20
# 133/133 [==============================] - 18s 138ms/step - loss: 0.0016
# Epoch 4/20
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0015
# Epoch 5/20
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0013
# Epoch 6/20
# 133/133 [==============================] - 18s 135ms/step - loss: 0.0012
# Epoch 7/20
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0013
# Epoch 8/20
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0011
# Epoch 9/20
# 133/133 [==============================] - 18s 135ms/step - loss: 0.0011
# Epoch 10/20
# 133/133 [==============================] - 18s 134ms/step - loss: 9.8611e-04
# Epoch 11/20
# 133/133 [==============================] - 18s 135ms/step - loss: 0.0012
# Epoch 12/20
# 133/133 [==============================] - 18s 135ms/step - loss: 0.0011
# Epoch 13/20
# 133/133 [==============================] - 18s 137ms/step - loss: 0.0010
# Epoch 14/20
# 133/133 [==============================] - 18s 135ms/step - loss: 9.6134e-04
# Epoch 15/20
# 133/133 [==============================] - 18s 135ms/step - loss: 9.0931e-04
# Epoch 16/20
# 133/133 [==============================] - 18s 136ms/step - loss: 0.0010
# Epoch 17/20
# 133/133 [==============================] - 18s 136ms/step - loss: 9.8248e-04
# Epoch 18/20
# 133/133 [==============================] - 18s 134ms/step - loss: 0.0010
# Epoch 19/20
# 133/133 [==============================] - 18s 137ms/step - loss: 8.0733e-04
# Epoch 20/20
# 133/133 [==============================] - 18s 135ms/step - loss: 9.0536e-04

# %%
dataset_test = df_test.toPandas()
real_stock_price = dataset_test.iloc[:, 6:7].values
# Out:
# /usr/local/spark/python/pyspark/sql/pandas/conversion.py:248: FutureWarning: Passing unit-less datetime64 dtype to .astype is deprecated and will raise in a future version. Pass 'datetime64[ns]' instead
#   series = series.astype(t, copy=False)

# %%
# Tiến hành dự đoán 
dataset_total = pd.concat((dataset_train['mean'], dataset_test['mean']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

X_test = []
no_of_sample = len(inputs)

for i in range(60, no_of_sample):
    X_test.append(inputs[i-60:i, 0])

X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# /tmp/ipykernel_571/2564601041.py:3: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
# 7/7 [==============================] - 1s 34ms/step

# %%
# Ve bieu do gia that va gia du doan
plt.figure(figsize=(16,9))
plt.plot(real_stock_price, color = 'red', label = 'Real VIC Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted VIC Stock Price')
plt.title('VIC Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('VIC Stock Price')
plt.legend()
plt.show()

# %%
spark.stop()

# %%
Image("spark_st.png")
